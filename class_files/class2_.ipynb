# %%
pip install seaborn numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import Statements
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Exploratory Data - KC Housing Data

# %%
# Import data into environment, KC_House_Data
kc_house_data = "https://raw.githubusercontent.com/delinai/schulich_ds1/main/Datasets/kc_house_data.csv"
df = pd.read_csv(kc_house_data)

# %%
# Pandas is used for exploring, cleaning before Machine Learning and modelling
# Pandas is great for exploration
# PySpark - more for bigger data, millions of rows, since Pandas does get slower sometimes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
# Quick preview:
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
# Look at parts of it
df.iloc[:,11:].head() # pull everything from 11th column
# Out:
#    grade  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0      7        1180              0      1955             0    98178  47.5112
# 1      7        2170            400      1951          1991    98125  47.7210
# 2      6         770              0      1933             0    98028  47.7379
# 3      7        1050            910      1965             0    98136  47.5208
# 4      8        1680              0      1987             0    98074  47.6168
#
#       long  sqft_living15  sqft_lot15
# 0 -122.257           1340        5650
# 1 -122.319           1690        7639
# 2 -122.233           2720        8062
# 3 -122.393           1360        5000
# 4 -122.045           1800        7503

# %%
# Script vs. Notebooks
# Script - run the whole thing at once
# Notebooks - run pieces of code
df.iloc[:,:11].head() # pull everything up to 11th column
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition
# 0      5650     1.0           0     0          3
# 1      7242     2.0           0     0          3
# 2     10000     1.0           0     0          3
# 3      5000     1.0           0     0          5
# 4      8080     1.0           0     0          3

# %% [markdown]
# # Practice Questions:
# Practice Example - What should be the output variable?
# - price
#
#
# What are the input variables that relevant?
# - date sold, correlation coefficients
# - sft
# - location
# - year renovation
# - condition
#
# * what data do you not have? How do you factor for it?
#
# What would you like to analyze given the dataset?
# What is your hypothesis?
# - everything, sft, location, year renovated, condition of house, view matters will affect prie

# %%
check = df[["waterfront","view"]]

check.sort_values(by = "waterfront",ascending = True)
# Out:
#        waterfront  view
# 0               0     0
# 14382           0     0
# 14381           0     0
# 14380           0     3
# 14379           0     2
# ...           ...   ...
# 12935           1     4
# 4218            1     3
# 14619           1     4
# 16333           1     4
# 6102            1     2
#
# [21613 rows x 2 columns]

# %%
check = df["waterfront"].value_counts()
check
# Out:
# waterfront
# 0    21450
# 1      163
# Name: count, dtype: int64

# %%
# Check Correlation Matrix
new_data = df.loc[:, df.columns != 'date']

check = new_data.corr()

check
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
# Data Clean up
# Google for the data dictionary - what each column represents
# You may need an internal data dictionary or someone to explain
# Non-Null Count, there is no missing data

# Data Type - for example, date is captured as a step for cleaning, if we plan to do time-series analysis
# Price - it's a floating point, which we expect, decimal

# If data type varies by row, it will set entire column as object

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
plt.matshow(new_data.corr())
plt.show()

# %%
# Descriptive Statistics of each one
df.iloc[:,11:].describe()
# Out:
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# ...

# %%
# When we have consistent data, it would hover around the average
# If our data follows a normal distribution 

# Empricial rule
# 66% of data would fall within 1 standard deviations both ways

# 5.4 - 3.67
one_deviation_up = 5.4 + 3.67
one_deviation_up

# range
# Out:
# 9.07

# %%
# Compare 50% and std

# From this dataset, you can see it's more right-skewed
# Some dedications, like lack of information can imply a different building type

# i.e. bachelor condos or empty lots

# bedrooms = 33


# Categorical variables
# some variable, like name of column, then binary (0 or 1), yes or no, binary 

# View - up to 4 views

# Condition 1 = bad, 5 = bad

# Grade of material  - middle ground

# sqft_above 

# sqft_basement

# if you add sqft_above + sqft_basement = should add to total sqft_living

# yr_built - huge range

# yr_renovated - some in 90s and some in 2015

# zipcode - 

# neighbouring homes, nearby 15 closest

# Do not remove any columns until you know for absolute certainity, from data-driven

# %%
# Select numerical columns
df.iloc[:,2:].corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308350   0.525138     0.702035  0.089661  0.256794
# bedrooms       0.308350  1.000000   0.515884     0.576671  0.031703  0.175429
# bathrooms      0.525138  0.515884   1.000000     0.754665  0.087740  0.500653
# sqft_living    0.702035  0.576671   0.754665     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.031703   0.087740     0.172826  1.000000 -0.005201
# floors         0.256794  0.175429   0.500653     0.353949 -0.005201  1.000000
# waterfront     0.266369 -0.006582   0.063744     0.103818  0.021604  0.023698
# view           0.397293  0.079532   0.187737     0.284611  0.074710  0.029444
# condition      0.036362  0.028472  -0.124982    -0.058753 -0.008958 -0.263768
# grade          0.667434  0.356967   0.664983     0.762704  0.113621  0.458183
# sqft_above     0.605567  0.477600   0.685342     0.876597  0.183512  0.523885
# ...

# %%
plt.figure(figsize = (15,15))
sns.heatmap(df.iloc[:,2:].corr(), annot = True)


# Remember - this is Pearson R!
# -0.3 to 0.3 - weak
# positive 0.3 to 0.7 - moderate strength
# anything higher than 0.7 - strong relationship

# Remember - we have not any cleaning - so it might change

# Think carefully about how to analyze your data

# if you have to conclude when they could be relevant 
# for example, price ranges might have different factors that heavily affect it
# Out:
# <Axes: >

# %%
# Clean up - class level function
# Series and Data Frames, and not to series / data frames
# This function below can be applied to both
df["date"] = pd.to_datetime(df["date"])

# Time Stamp

# %%
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
# If something weird is going on, use a box plot

# Use matplotlib or seaborn

# Use Seaborn
new_plot = sns.boxplot(y = df["bathrooms"])

# %%
# Quartiles, sections of your data

# most bottom line - the minimum 

# middle line = median - 50% are above the value

# toppest data point = maximum, bottom is minimum

# 1.75 to 2.25 = 2nd quartile
# 2.25 to 2.5 = 3rd quarticle - 75% of data
# 2.5 to 3.5 = 4th quartile

# how many outliers - we have a lot for bedrooms!!

# first quartile


# second quartile


# third quartile


# fourth quartile


# example - top 1% may account for a lot of the revenue

# we might want to look at top x %, for when we want to divide into subsections, versus bottom %

# How to treat outliers - 
    # you don't necessarily want to drop it, but you can

    # Replace the extreme values with a certain percentile - do it at 99% percentile

    # replace 7 bathrooms, and put 3.5 bathrooms
    # track homes with over 3.5 bathrooms


# example - whales
# spend $1000 per day on average for gaming
# $1000 person spending at the maximum, so we assume they're around that range
# normalize but we don't lose the person, what their behaviour is


# why not drop outliers?
    # drop outliers if you're looking at the average person, then you can ignore the outliers


# You can also just looking at each person separately, outliers and the average person

# Data-driven person, why drop outliers? Define the reason why

# How to isolate?

# %%
investigation = df[df["bathrooms"] > 3.75] # look for greater than 3.75
investigation

investigation.describe() # gives hint on what to do

# Very expensive house is still in there
# Out:
#                  id                           date         price    bedrooms  \
# count  4.020000e+02                            402  4.020000e+02  402.000000
# mean   3.879148e+09  2014-10-20 15:31:20.597015040  1.534396e+06    4.815920
# min    4.200013e+07            2014-05-05 00:00:00  2.650000e+05    3.000000
# 25%    1.534989e+09            2014-07-09 06:00:00  8.659250e+05    4.000000
# 50%    3.314390e+09            2014-10-07 00:00:00  1.265390e+06    5.000000
# 75%    6.070925e+09            2015-01-26 00:00:00  1.915000e+06    5.000000
# max    9.822700e+09            2015-05-12 00:00:00  7.700000e+06   10.000000
# std    2.779870e+09                            NaN  1.032948e+06    1.087652
#
#         bathrooms   sqft_living       sqft_lot      floors  waterfront  \
# count  402.000000    402.000000     402.000000  402.000000  402.000000
# mean     4.468905   4640.258706   34981.236318    1.971393    0.054726
# ...

# %%
# With winzeridation - you need to be careful with your technique selection, every single characteristic is different

# Drop specific outliers, for example, luxury homes

luxury_homes = df[df["bathrooms"] > 3.75]

# %%
df_no_luxury = df.drop(luxury_homes.index) # drop homes higher than 3.75 bedrooms

# %%
df_no_luxury
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
# Process of winzerization 
# replace outliers

sns.boxplot(y = df_no_luxury["bedrooms"]) # even with removal, it's still pretty big
# Out:
# <Axes: ylabel='bedrooms'>

# %%
df_no_luxury[df_no_luxury["bedrooms"] > 5].describe()
# Out:
#                  id                           date         price    bedrooms  \
# count  2.510000e+02                            251  2.510000e+02  251.000000
# mean   4.521833e+09  2014-11-01 09:22:13.864541952  6.813650e+05    6.342629
# min    1.000102e+06            2014-05-05 00:00:00  1.750000e+05    6.000000
# 25%    2.225059e+09            2014-07-17 00:00:00  4.200000e+05    6.000000
# 50%    3.975400e+09            2014-11-04 00:00:00  6.200000e+05    6.000000
# 75%    6.918720e+09            2015-02-16 00:00:00  8.190000e+05    6.000000
# max    9.558041e+09            2015-05-06 00:00:00  2.885000e+06   33.000000
# std    2.755326e+09                            NaN  3.727304e+05    1.824866
#
#         bathrooms  sqft_living       sqft_lot      floors  waterfront  \
# count  251.000000   251.000000     251.000000  251.000000  251.000000
# mean     2.665339  2975.772908   15590.334661    1.515936    0.003984
# ...

# %%
# WINSORIZE 
# % percentage replacement - like 5 is the biggest data for bedrooms

# Depends on the use case that you are doing this

# If you are building a general analysis of homes, such as influence pricing, then don't drop the outliers
# if you were specific, like real-estate agent and you don't sell luxury homes, then you might want to drop them
# Use case for your data is the most important thing

# you need to explain why it's the best treatment

# %%
pip install scipy

# Statistics testing A/B and Winsorization
# Out:
#   Cell In[141], line 1
#     pip install scipy
#         ^
# SyntaxError: invalid syntax

# %%
# example of winsoriztion 

from scipy import stats

df_no_luxury["bedrooms_winsorized"] = stats.mstats.winsorize(df_no_luxury["bedrooms"], limits =[0.05,0.95])

# 75TH pecniel is at

# %%
df_no_luxury["sqft_living_winsorized"] = stats.mstats.winsorize(df_no_luxury["sqft_living"], limits =[0.2,0.2])
df_no_luxury["sqft_living_chg"] = df_no_luxury["sqft_living_winsorized"] - df_no_luxury["sqft_living"]

df_no_luxury
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df_no_luxury["sqft_living_winsorized"] = stats.mstats.winsorize(df_no_luxury["sqft_living"], limits =[0.2,0.2])
#       2 df_no_luxury["sqft_living_chg"] = df_no_luxury["sqft_living_winsorized"] - df_no_luxury["sqft_living"]
#       4 df_no_luxury
#
# NameError: name 'stats' is not defined

# %%
# # Drop irrelvant columns

# df_no_luxury.drop("id", axis = 1, inplace = True)

# # This will drop ID

# %%
df_no_luxury[["sqft_living", "sqft_living_winsorized"]]
# Out:
#        sqft_living  sqft_living_winsorized
# 0             1180                    1320
# 1             2570                    2570
# 2              770                    1320
# 3             1960                    1960
# 4             1680                    1680
# ...            ...                     ...
# 21608         1530                    1530
# 21609         2310                    2310
# 21610         1020                    1320
# 21611         1600                    1600
# 21612         1020                    1320
#
# [21211 rows x 2 columns]

# %%
df_no_luxury[["bedrooms", "bedrooms_winsorized"]]
# Out:
#        bedrooms  bedrooms_winsorized
# 0             3                    2
# 1             3                    2
# 2             2                    2
# 3             4                    2
# 4             3                    2
# ...         ...                  ...
# 21608         3                    2
# 21609         4                    2
# 21610         2                    2
# 21611         3                    2
# 21612         2                    2
#
# [21211 rows x 2 columns]

# %%
df_no_luxury.describe()
# Out:
# /Users/christine/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4737: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# /Users/christine/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4737: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# /Users/christine/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4737: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# /Users/christine/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4737: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# /Users/christine/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4737: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# ...

# %%
# Extract data from different values

# Feature Engineers - generate datapoints from existing data points

# Extract from date

# Create month data
# df_no_luxury['sale_month'] = pd.DatetimeIndex(df['date']).month
df_no_luxury["sale_month_2"] = df_no_luxury["date"].apply(lambda x: x.month)

# %%
df_no_luxury.head(10)
# Out:
#             id       date     price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520 2014-10-13  221900.0         3       1.00         1180
# 1   6414100192 2014-12-09  538000.0         3       2.25         2570
# 2   5631500400 2015-02-25  180000.0         2       1.00          770
# 3   2487200875 2014-12-09  604000.0         4       3.00         1960
# 4   1954400510 2015-02-18  510000.0         3       2.00         1680
# 6   1321400060 2014-06-27  257500.0         3       2.25         1715
# 7   2008000270 2015-01-15  291850.0         3       1.50         1060
# 8   2414600126 2015-04-15  229500.0         3       1.00         1780
# 9   3793500160 2015-03-12  323000.0         3       2.50         1890
# 10  1736800520 2015-04-03  662500.0         3       2.50         3560
#
#     sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0       5650     1.0           0     0  ...        1180              0
# ...

# %%
# Depending your definition, you could define x sqft as a condo and apply to the data frame

# Synthetic data - follow pattern or trend as original data but it's fake
# This data is real

# Generate synthetic data for model training, i.e. not enough data and then generate some data to help enrich so that it can work

# we might do for privacy data, i.e. cannot use user data

# may use feature engineering that's meaningful, as cross-functional, so synthesize

# Generate new data points as it might help the model interpret the patterns better

# %%
plt.figure(figsize = (15,15))
sns.heatmap(df_no_luxury.corr(), annot = True)
# Out:
# <Axes: >

# %%
sns.boxplot()

# Sqft in price, it makes sense to check pearson_r, we can see a relationship
# Grade variable 

# Are all the plots cheaper, more expensive?
# 


sns.scatterplot(x = df_no_luxury['grade'], y= df_no_luxury['price'], data = df_no_luxury)
# Out:
# <Axes: xlabel='grade', ylabel='price'>

# %%
# use the box plot
sns.boxplot(x = df_no_luxury['grade'], y= df_no_luxury['price'], data = df_no_luxury)

# Grade is categorical, so medium price is over 2 million dollars
# really high finishes or material grade
# distribution varies a lot by grade
# Out:
# <Axes: xlabel='grade', ylabel='price'>

# %%
sns.boxplot(x = df_no_luxury['view'], y= df_no_luxury['price'], data = df_no_luxury)
# Out:
# <Axes: xlabel='view', ylabel='price'>

# %%
# Use box plot

# scatterplot - continous x and continous y 
# box plot - categorical x and continous y

# box plot can also be used to determine outliers and map categorical + continous y

df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.iloc[:,2:].describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...
